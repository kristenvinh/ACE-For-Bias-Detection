# %%
import sys
import os
import numpy as np
import sklearn.metrics as metrics
from tcav import utils
import tcav.utils_plot as utils_plot # utils_plot requires matplotlib
import tensorflow as tf
import ace_helpers
from ace import ConceptDiscovery
import os
import shutil
import random

# %%
def create_image_folders(source_path, num_random_exp, max_imgs):
  # Get all image paths from male and female folders
  image_paths = []
  for gender in ["male", "female"]:
    gender_path = os.path.join(source_path, gender)
    for filename in os.listdir(gender_path):
      if filename.endswith(('.jpg', '.jpeg', '.png')):  # Add other image extensions if needed
        image_paths.append(os.path.join(gender_path, filename))

  # Create "random_discovery" folders
    folder_name = "random_discovery"
    folder_path = os.path.join(source_path, folder_name)
    os.makedirs(folder_path, exist_ok=True)
    selected_images = random.sample(image_paths, max_imgs)
    for image_path in selected_images:
      shutil.copy(image_path, folder_path)

  # Create "random500_" folders
  for i in range(num_random_exp):
    folder_name = "random500_" + str(i)
    folder_path = os.path.join(source_path, folder_name)
    os.makedirs(folder_path, exist_ok=True)
    selected_images = random.sample(image_paths, 500)
    for image_path in selected_images:
      shutil.copy(image_path, folder_path)

# Example usage:
source_path = 'part1' # Replace with the actual path
create_image_folders(source_path, num_random_exp, max_imgs)

# %%
# !python3 ace_run.py --source_dir part1 --working_dir SAVE_DIR --model_to_run custom --model_path models/gender_classification.h5 --target_class male --labels_path labels.txt --bottlenecks global_average_pooling2d --num_random_exp 20 --max_imgs 50 --min_imgs 30

# %%
#Set variables for running code using the "female class "
source_dir = 'part1'
working_dir = 'male_save_dir_11.2'
model_to_run = 'custom'
model_path = "models/gender_classification.h5"
labels_path = 'labels.txt'
bottlenecks= 'global_average_pooling2d_4' 
num_random_exp = 20 
max_imgs = 50 
min_imgs = 30
target_class = 'male'

# %%
#Set up folders
discovered_concepts_dir = os.path.join(working_dir, 'concepts/')
results_dir = os.path.join(working_dir, 'results/')
cavs_dir = os.path.join(working_dir, 'cavs/')
activations_dir = os.path.join(working_dir, 'acts/')
results_summaries_dir = os.path.join(working_dir, 'results_summaries/')
if tf.io.gfile.exists(working_dir):
    tf.io.gfile.rmtree(working_dir)
tf.io.gfile.makedirs(working_dir)
tf.io.gfile.makedirs(discovered_concepts_dir)
tf.io.gfile.makedirs(results_dir)
tf.io.gfile.makedirs(cavs_dir)
tf.io.gfile.makedirs(activations_dir)
tf.io.gfile.makedirs(results_summaries_dir)
random_concept = 'random_discovery'  # Random concept for statistical testing

# %%
#Create session and model
sess = utils.create_session()
mymodel = ace_helpers.make_model(
    sess, model_to_run, model_path, labels_path)
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.10/site-packages/keras/layers/normalization/batch_normalization.py:581: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2024-11-02 14:07:45.940611: W tensorflow/c/c_api.cc:300] Operation '{name:'block_15_expand_BN/moving_mean/Assign' id:1957 op device:{requested: '', assigned: ''} def:{{{node block_15_expand_BN/moving_mean/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](block_15_expand_BN/moving_mean, block_15_expand_BN/moving_mean/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-02 14:07:46.204908: W tensorflow/c/c_api.cc:300] Operation '{name:'Conv_1_bn/beta/v/Assign' id:4011 op device:{requested: '', assigned: ''} def:{{{node Conv_1_bn/beta/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](Conv_1_bn/beta/v, Conv_1_bn/beta/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
# Creating the ConceptDiscovery class instance
cd = ConceptDiscovery(
    mymodel,
    target_class,
    random_concept,
    bottlenecks.split(','),
    sess,
    source_dir,
    activations_dir,
    cavs_dir,
    num_random_exp=num_random_exp,
    channel_mean=True,
    max_imgs=max_imgs,
    min_imgs=min_imgs,
    num_discovery_imgs =max_imgs)

# %%
  # Creating the dataset of image patches
  cd.create_patches(param_dict={'n_segments': [15, 50, 80]})

# %%
  # Saving the concept discovery target class images
  image_dir = os.path.join(discovered_concepts_dir, 'images')
  tf.io.gfile.makedirs(image_dir)
  ace_helpers.save_images(image_dir,
                            (cd.discovery_images * 256).astype(np.uint8))

# %%
 # Discovering Concepts
cd.discover_concepts(method='KM', param_dicts={'n_clusters': 25})
del cd.dataset  # Free memory
del cd.image_numbers
del cd.patches
# Out:
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
  # Save discovered concept images (resized and original sized)
  ace_helpers.save_concepts(cd, discovered_concepts_dir)

# %%
  # Calculating CAVs and TCAV scores
  cav_accuraciess = cd.cavs(min_acc=0.0)
  scores = cd.tcavs(test=False)
# Out:
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_12': 0.8125, 'overall': 0.9090909090909091}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_12': 0.8125, 'overall': 0.9090909090909091}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_6': 0.8823529411764706, 'overall': 0.9393939393939394}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_6': 0.8823529411764706, 'overall': 0.9393939393939394}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 0.875, 'random500_16': 1.0, 'overall': 0.9393939393939394}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 0.875, 'random500_16': 1.0, 'overall': 0.9393939393939394}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_15'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_18'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept1', 'random500_17'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept1': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept1': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_17'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_18'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_15'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept2', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_19': 0.9411764705882353, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_6': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_19': 0.9411764705882353, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_6': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept2': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept2': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_15'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_4': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_16': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_17'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept3', 'random500_18'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_4': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_6': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_16': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_6': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_10': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept3': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_10': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept3': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_15'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_17'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept4', 'random500_18'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_6': 0.875, 'overall': 0.9393939393939394}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_9': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_8': 0.9411764705882353, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_6': 0.875, 'overall': 0.9393939393939394}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_9': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_8': 0.9411764705882353, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept4': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept4': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_15'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_18'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_17'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept5', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_5': 0.9411764705882353, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_6': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_14': 0.9411764705882353, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_5': 0.9411764705882353, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_6': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept5': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_14': 0.9411764705882353, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept5': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_17'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_18'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_1': 0.875, 'overall': 0.9393939393939394}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_8': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept6', 'random500_15'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_6': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_1': 0.875, 'overall': 0.9393939393939394}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_8': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_6': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept6': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept6': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_17'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_15'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_18'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept7', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_6': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_6': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_12': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_18': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:acc per class {'male_concept7': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_8': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_16': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_18': 0.9375, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'male_concept7': 1.0, 'random500_19': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male_concept8', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# ...
# INFO:tensorflow:CAV accuracies: {'male_concept24': 1.0, 'random500_13': 1.0, 'overall': 1.0}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male_concept24': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept24': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept24': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept24': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:acc per class {'male_concept24': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'male_concept24': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:Training CAV ['male', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male', 'random500_15'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['male', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male': 0.625, 'random500_0': 0.6470588235294118, 'overall': 0.6363636363636364}
# INFO:tensorflow:acc per class {'male': 0.1875, 'random500_1': 0.6470588235294118, 'overall': 0.42424242424242425}
# INFO:tensorflow:Training CAV ['male', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male': 0.23529411764705882, 'random500_13': 0.875, 'overall': 0.5454545454545454}
# INFO:tensorflow:Training CAV ['male', 'random500_17'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['male', 'random500_18'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'male': 0.1875, 'random500_14': 0.8235294117647058, 'overall': 0.5151515151515151}
# INFO:tensorflow:acc per class {'male': 0.17647058823529413, 'random500_15': 0.6875, 'overall': 0.42424242424242425}
# INFO:tensorflow:acc per class {'male': 0.5294117647058824, 'random500_3': 0.6875, 'overall': 0.6060606060606061}
# INFO:tensorflow:acc per class {'male': 0.17647058823529413, 'random500_2': 0.625, 'overall': 0.3939393939393939}
# INFO:tensorflow:acc per class {'male': 0.17647058823529413, 'random500_5': 0.75, 'overall': 0.45454545454545453}
# INFO:tensorflow:acc per class {'male': 0.8823529411764706, 'random500_6': 0.1875, 'overall': 0.5454545454545454}
# INFO:tensorflow:acc per class {'male': 0.7647058823529411, 'random500_4': 0.1875, 'overall': 0.48484848484848486}
# INFO:tensorflow:acc per class {'male': 0.5294117647058824, 'random500_8': 0.6875, 'overall': 0.6060606060606061}
# INFO:tensorflow:CAV accuracies: {'male': 0.625, 'random500_0': 0.6470588235294118, 'overall': 0.6363636363636364}
# INFO:tensorflow:acc per class {'male': 0.8235294117647058, 'random500_11': 0.625, 'overall': 0.7272727272727273}
# INFO:tensorflow:acc per class {'male': 0.5625, 'random500_7': 0.29411764705882354, 'overall': 0.42424242424242425}
# INFO:tensorflow:acc per class {'male': 0.7647058823529411, 'random500_10': 0.1875, 'overall': 0.48484848484848486}
# INFO:tensorflow:CAV accuracies: {'male': 0.1875, 'random500_1': 0.6470588235294118, 'overall': 0.42424242424242425}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male': 0.23529411764705882, 'random500_13': 0.875, 'overall': 0.5454545454545454}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'male': 0.25, 'random500_9': 0.6470588235294118, 'overall': 0.45454545454545453}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'male': 0.1875, 'random500_14': 0.8235294117647058, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'male': 0.17647058823529413, 'random500_15': 0.6875, 'overall': 0.42424242424242425}
# INFO:tensorflow:acc per class {'male': 0.7647058823529411, 'random500_12': 0.25, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'male': 0.5294117647058824, 'random500_3': 0.6875, 'overall': 0.6060606060606061}
# INFO:tensorflow:acc per class {'male': 0.8235294117647058, 'random500_17': 0.0, 'overall': 0.42424242424242425}
# INFO:tensorflow:CAV accuracies: {'male': 0.17647058823529413, 'random500_2': 0.625, 'overall': 0.3939393939393939}
# INFO:tensorflow:CAV accuracies: {'male': 0.17647058823529413, 'random500_5': 0.75, 'overall': 0.45454545454545453}
# INFO:tensorflow:CAV accuracies: {'male': 0.8823529411764706, 'random500_6': 0.1875, 'overall': 0.5454545454545454}
# INFO:tensorflow:CAV accuracies: {'male': 0.7647058823529411, 'random500_4': 0.1875, 'overall': 0.48484848484848486}
# INFO:tensorflow:CAV accuracies: {'male': 0.5294117647058824, 'random500_8': 0.6875, 'overall': 0.6060606060606061}
# INFO:tensorflow:CAV accuracies: {'male': 0.8235294117647058, 'random500_11': 0.625, 'overall': 0.7272727272727273}
# INFO:tensorflow:CAV accuracies: {'male': 0.5625, 'random500_7': 0.29411764705882354, 'overall': 0.42424242424242425}
# INFO:tensorflow:CAV accuracies: {'male': 0.7647058823529411, 'random500_10': 0.1875, 'overall': 0.48484848484848486}
# INFO:tensorflow:acc per class {'male': 0.47058823529411764, 'random500_16': 0.375, 'overall': 0.42424242424242425}
# INFO:tensorflow:CAV accuracies: {'male': 0.25, 'random500_9': 0.6470588235294118, 'overall': 0.45454545454545453}
# INFO:tensorflow:acc per class {'male': 0.3125, 'random500_18': 0.8235294117647058, 'overall': 0.5757575757575758}
# INFO:tensorflow:CAV accuracies: {'male': 0.7647058823529411, 'random500_12': 0.25, 'overall': 0.5151515151515151}
# INFO:tensorflow:acc per class {'male': 0.375, 'random500_19': 0.6470588235294118, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'male': 0.8235294117647058, 'random500_17': 0.0, 'overall': 0.42424242424242425}
# INFO:tensorflow:CAV accuracies: {'male': 0.47058823529411764, 'random500_16': 0.375, 'overall': 0.42424242424242425}
# INFO:tensorflow:CAV accuracies: {'male': 0.3125, 'random500_18': 0.8235294117647058, 'overall': 0.5757575757575758}
# INFO:tensorflow:CAV accuracies: {'male': 0.375, 'random500_19': 0.6470588235294118, 'overall': 0.5151515151515151}
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_0'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_2'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_3'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_1'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_6'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_7'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_10'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_5'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_12'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_4'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_13'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_11'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_15'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_14'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_18'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_19'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'random_discovery': 0.7647058823529411, 'random500_0': 0.375, 'overall': 0.5757575757575758}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'random_discovery': 0.6875, 'random500_12': 0.47058823529411764, 'overall': 0.5757575757575758}
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_9'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_8'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'random_discovery': 0.875, 'random500_11': 0.11764705882352941, 'overall': 0.48484848484848486}
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_16'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'random_discovery': 0.375, 'random500_15': 0.5882352941176471, 'overall': 0.48484848484848486}
# INFO:tensorflow:Training CAV ['random_discovery', 'random500_17'] - global_average_pooling2d_4 alpha 0.01
# INFO:tensorflow:acc per class {'random_discovery': 0.75, 'random500_14': 0.29411764705882354, 'overall': 0.5151515151515151}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'random_discovery': 0.17647058823529413, 'random500_18': 0.5625, 'overall': 0.36363636363636365}
# INFO:tensorflow:acc per class {'random_discovery': 0.625, 'random500_19': 0.5882352941176471, 'overall': 0.6060606060606061}
# INFO:tensorflow:acc per class {'random_discovery': 0.5625, 'random500_6': 0.35294117647058826, 'overall': 0.45454545454545453}
# INFO:tensorflow:acc per class {'random_discovery': 0.625, 'random500_7': 0.17647058823529413, 'overall': 0.3939393939393939}
# INFO:tensorflow:acc per class {'random_discovery': 0.5, 'random500_10': 0.6470588235294118, 'overall': 0.5757575757575758}
# INFO:tensorflow:acc per class {'random_discovery': 0.5294117647058824, 'random500_5': 0.375, 'overall': 0.45454545454545453}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.7647058823529411, 'random500_0': 0.375, 'overall': 0.5757575757575758}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.6875, 'random500_12': 0.47058823529411764, 'overall': 0.5757575757575758}
# INFO:tensorflow:acc per class {'random_discovery': 0.4117647058823529, 'random500_4': 0.5, 'overall': 0.45454545454545453}
# INFO:tensorflow:acc per class {'random_discovery': 0.47058823529411764, 'random500_2': 0.3125, 'overall': 0.3939393939393939}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:acc per class {'random_discovery': 0.5882352941176471, 'random500_9': 0.4375, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.875, 'random500_11': 0.11764705882352941, 'overall': 0.48484848484848486}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.375, 'random500_15': 0.5882352941176471, 'overall': 0.48484848484848486}
# INFO:tensorflow:acc per class {'random_discovery': 0.625, 'random500_13': 0.47058823529411764, 'overall': 0.5454545454545454}
# INFO:tensorflow:training with alpha=0.01
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.75, 'random500_14': 0.29411764705882354, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.17647058823529413, 'random500_18': 0.5625, 'overall': 0.36363636363636365}
# INFO:tensorflow:acc per class {'random_discovery': 0.6470588235294118, 'random500_1': 0.375, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.625, 'random500_19': 0.5882352941176471, 'overall': 0.6060606060606061}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.5625, 'random500_6': 0.35294117647058826, 'overall': 0.45454545454545453}
# INFO:tensorflow:acc per class {'random_discovery': 0.5625, 'random500_3': 0.6470588235294118, 'overall': 0.6060606060606061}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.625, 'random500_7': 0.17647058823529413, 'overall': 0.3939393939393939}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.5, 'random500_10': 0.6470588235294118, 'overall': 0.5757575757575758}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.5294117647058824, 'random500_5': 0.375, 'overall': 0.45454545454545453}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.4117647058823529, 'random500_4': 0.5, 'overall': 0.45454545454545453}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.5882352941176471, 'random500_9': 0.4375, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.47058823529411764, 'random500_2': 0.3125, 'overall': 0.3939393939393939}
# INFO:tensorflow:acc per class {'random_discovery': 0.6470588235294118, 'random500_8': 0.375, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.625, 'random500_13': 0.47058823529411764, 'overall': 0.5454545454545454}
# INFO:tensorflow:acc per class {'random_discovery': 0.4117647058823529, 'random500_16': 0.6875, 'overall': 0.5454545454545454}
# INFO:tensorflow:acc per class {'random_discovery': 0.23529411764705882, 'random500_17': 0.5, 'overall': 0.36363636363636365}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.6470588235294118, 'random500_1': 0.375, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.5625, 'random500_3': 0.6470588235294118, 'overall': 0.6060606060606061}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.6470588235294118, 'random500_8': 0.375, 'overall': 0.5151515151515151}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.4117647058823529, 'random500_16': 0.6875, 'overall': 0.5454545454545454}
# INFO:tensorflow:CAV accuracies: {'random_discovery': 0.23529411764705882, 'random500_17': 0.5, 'overall': 0.36363636363636365}

# %%
# Delete concepts that don't pass statistical testing
cd.test_and_remove_concepts(scores)

# %%
#Generate ace report after concepts have been removed
ace_helpers.save_ace_report(cd, cav_accuraciess, scores,
                                 results_summaries_dir + 'ace_results.txt')

# %%
#Get a list concepts above a certain TCAV score: 
def get_concepts_above_threshold(file_path, threshold):
  concepts = []
  with open(file_path, 'r') as file:
    for line in file:
        if "global" in line:
          parts = line.split(":")
          score = parts[2].split(",")[0]
          if float(score) > threshold:
            concepts.append(parts[1])
  return concepts

# %%
#Run above function
concepts = get_concepts_above_threshold('male_save_dir_11.2/results_summaries/ace_results.txt', .5)

# Plot examples of discovered concepts
for bn in cd.bottlenecks:
  ace_helpers.plot_concepts(cd, bn, 5, address=results_dir, mode='diverse', concepts=concepts)
